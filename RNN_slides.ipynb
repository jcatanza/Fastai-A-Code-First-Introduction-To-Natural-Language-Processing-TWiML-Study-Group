# %%
from IPython.display import Image

# %%
Image("standard_RNN.PNG")

# %%
Image("RNN_state_update_and_output.PNG")

# %%
Image("RNN_computational_graph_across_time.PNG")

# %%
Image("RNNs_backpropagation_through_time.PNG")

# %%
Image("RNN_exploding_gradients.PNG")

# %%
Image("RNN_vanishing_gradients.PNG")
