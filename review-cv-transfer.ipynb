# %% [markdown]
# # Review: computer vision transfer learning

# %% [markdown]
# This is a subset of lesson 1 of https://course.fast.ai <br>
# Joseph Catanzarite's Note: I did not refactor or annotate this notebook, because it is perfect!!

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from fastai.vision import *
from fastai.metrics import error_rate

# %%
bs = 64
# bs = 16   # uncomment this line if you run out of memory even after clicking Kernel->Restart

# %% [markdown]
# We are going to use the [Oxford-IIIT Pet Dataset](http://www.robots.ox.ac.uk/~vgg/data/pets/) by [O. M. Parkhi et al., 2012](http://www.robots.ox.ac.uk/~vgg/publications/2012/parkhi12a/parkhi12a.pdf) which features 12 cat breeds and 25 dogs breeds. Our model will need to learn to differentiate between these 37 distinct categories. According to their paper, the best accuracy they could get in 2012 was 59.21%.

# %%
path = untar_data(URLs.PETS)
path_anno = path/'annotations'
path_img = path/'images'
np.random.seed(2)
fnames = get_image_files(path_img)
fnames[0]
# Out:
# WindowsPath('C:/Users/cross-entropy/.fastai/data/oxford-iiit-pet/images/Abyssinian_1.jpg')

# %%
pat = r'/([^/]+)_\d+.jpg$'
data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(), size=224, bs=bs
                                  ).normalize(imagenet_stats)
data.show_batch(rows=3, figsize=(7,6))

# %% [markdown]
# ## Training

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.398183</td>
#       <td>0.354283</td>
#       <td>0.107578</td>
#       <td>01:33</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.616111</td>
#       <td>0.319888</td>
#       <td>0.096752</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.390652</td>
#       <td>0.264836</td>
#       <td>0.081191</td>
#       <td>01:30</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.291671</td>
#       <td>0.244715</td>
#       <td>0.071719</td>
#       <td>01:29</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.unfreeze()
learn.fit_one_cycle(2, max_lr=slice(1e-6,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.245862</td>
#       <td>0.234735</td>
#       <td>0.076455</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.216865</td>
#       <td>0.234753</td>
#       <td>0.072395</td>
#       <td>01:31</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.most_confused(min_val=2)
# Out:
# [('Ragdoll', 'Birman', 5),
#  ('chihuahua', 'miniature_pinscher', 5),
#  ('Birman', 'Ragdoll', 4),
#  ('Birman', 'Siamese', 4),
#  ('staffordshire_bull_terrier', 'american_pit_bull_terrier', 4),
#  ('British_Shorthair', 'Russian_Blue', 3),
#  ('Egyptian_Mau', 'Bengal', 3),
#  ('Maine_Coon', 'Persian', 3),
#  ('Maine_Coon', 'Ragdoll', 3),
#  ('american_bulldog', 'staffordshire_bull_terrier', 3),
#  ('american_pit_bull_terrier', 'american_bulldog', 3),
#  ('american_pit_bull_terrier', 'staffordshire_bull_terrier', 3),
#  ('english_cocker_spaniel', 'english_setter', 3),
#  ('miniature_pinscher', 'chihuahua', 3),
#  ('staffordshire_bull_terrier', 'american_bulldog', 3),
#  ('British_Shorthair', 'Bombay', 2),
#  ('Ragdoll', 'Siamese', 2),
#  ('Sphynx', 'chihuahua', 2),
#  ('american_bulldog', 'boxer', 2),
#  ('chihuahua', 'american_pit_bull_terrier', 2)]
